# %% [markdown]
# ## Introduction

# %% [markdown]
# This IPython notebook illustrates how to crawl the web-site https://portal.edirepository.org/nis/home.jsp to obtain the limnology data files. First we need to import bs4 and other libraries.

# %%
import cluster_attrs_edi as ca

# %% [markdown]
# Writes the attribute names found in the files in the given input folder to the given output file.
# 1. get_attr_names_frequency_order gives the attribute names sorted in the order of the frequency of the attribute names (in lower case)
# 2. get_attr_names_alphabetic_order gives the attribute names sorted in the alphabetic order (in lower case)

# %%
ca.get_attr_names_frequency_order('Limnology/csv-files','lowerCaseFrequencyOrder.csv')
ca.get_attr_names_alphabetic_order('Limnology/csv-files','lowerCaseAlphabeticOrder.csv')

# %% [markdown]
# Obtain a dictionary of the clustered attribute names and write the obtained sorted clusters into the given output file

# %%
dict = ca.cluster_attr_names('Limnology/csv-files','clusterAttributes_v4.csv')

# %% [markdown]
# Print the sorted clusters

# %%
ca.print_cluster_attr_names('Limnology/csv-files')
# Out:
# andate  216
# 	andate
# 	area
# 	area (m2)
# 	area.km2
# 	area_ha
# 	area_log
# 	avg_coredepth
# 	basin_prop_sampled
# 	basinarea_ha
# 	basinarea_km2
# 	basinarea_lu_km2
# 	basinareatolakearea_ha
# 	bufferarea_ha
# 	bufferarea_km2
# 	chemmeasid
# 	chemsampleid
# 	chi
# 	comments
# 	community_type
# 	concentration_max
# 	concentration_mean
# 	concentration_median
# 	concentration_min
# 	concentration_name
# 	concentration_unit
# 	core_depth
# 	core_site
# 	core_type
# 	coresite
# 	count
# 	countries
# 	country
# 	county
# 	creel_date
# 	creel_end
# 	creel_start
# 	creel_station
# 	date
# 	date_col
# 	date_time
# 	datestart
# 	decimal.date
# 	dep_m
# 	depth
# 	depth (m)
# 	depth.m
# 	depth/loc
# 	depth_interval
# 	depth_m
# 	depth_x
# 	depthcore
# 	depthcv
# 	depthgyttja
# 	depthid
# 	depthmax
# 	depthmean
# 	depthpeatft
# 	depthpeatft_old
# 	depthpeatm
# 	depthsd
# 	depthwt
# 	description
# 	drainage_area
# 	elevation
# 	elevation (m)
# 	elevation_m
# 	end_depth
# 	end_mesh
# ...
